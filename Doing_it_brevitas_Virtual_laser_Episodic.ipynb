# %%
import gym
import torch
from virtual_env import VirtualLaserEnv
from episodic_sac_brevitas import sac
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:87: RequestsDependencyWarning: urllib3 (2.2.2) or chardet (4.0.0) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
ac_kwargs = dict(hidden_sizes=[64,80], activation=torch.nn.ReLU)

logger_kwargs = dict(output_dir='test_virtual_env_brevitas', exp_name='lambda')

env = 'VirtualLaserEnv-v0'

# %%
sac(lambda : gym.make(env), alpha=0.001, lr=1e-4, ep_len=80, gradient_steps=80, ac_kwargs=ac_kwargs, logger_kwargs=logger_kwargs)
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# /usr/lib/python3/dist-packages/requests/__init__.py:87: RequestsDependencyWarning: urllib3 (2.2.2) or chardet (4.0.0) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# wandb: Currently logged in as: julii_tm (julii). Use `wandb login --relogin` to force relogin
# wandb version 0.17.5 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.17.3
# Run data is saved locally in <code>/home/juls/Desktop/PeRet_new/wandb/run-20240723_201316-80p9d7sm</code>
# Syncing run <strong><a href='https://wandb.ai/julii/test_simple/runs/80p9d7sm' target="_blank">upbeat-deluge-118</a></strong> to <a href='https://wandb.ai/julii/test_simple' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/julii/test_simple' target="_blank">https://wandb.ai/julii/test_simple</a>
#  View run at <a href='https://wandb.ai/julii/test_simple/runs/80p9d7sm' target="_blank">https://wandb.ai/julii/test_simple/runs/80p9d7sm</a>
# Logging data to test_virtual_env_brevitas/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             64,
#             80
#         ]
#     },
#     "actor_critic":	"MLPActorCritic",
#     "alpha":	0.001,
#     "batch_size":	100,
#     "device":	"cuda:1",
#     "env_fn":	"<function <lambda> at 0x76661e375cf0>",
#     "ep_len":	80,
#     "episodes_per_epoch":	10,
#     "epochs":	100,
#     "exp_name":	"lambda",
#     "gamma":	0.99,
#     "gradient_steps":	80,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x76660d1f7490>":	{
#             "epoch_dict":	{},
#             "exp_name":	"lambda",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"test_virtual_env_brevitas",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='test_virtual_env_brevitas/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"lambda",
#         "output_dir":	"test_virtual_env_brevitas"
#     },
#     "lr":	0.0001,
#     "num_test_episodes":	1,
#     "polyak":	0.995,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_episode":	100,
#     "update_after":	1
# }
# Data dictionary loaded successfully.
# Data dictionary loaded successfully.
# /home/juls/.local/lib/python3.10/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Number of parameters: 	 pi: 5557, 	 q1: 5537, 	 q2: 5537
# /usr/lib/python3/dist-packages/torch/_tensor.py:1419: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at ./c10/core/TensorImpl.h:1921.)
#   return super().rename(names)
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            8.44 |
# |          StdEpRet |           0.395 |
# |          MaxEpRet |            8.96 |
# |          MinEpRet |            7.89 |
# |  AverageTestEpRet |            6.33 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |            6.33 |
# |      MinTestEpRet |            6.33 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |             880 |
# |     AverageQ1Vals |           0.409 |
# |         StdQ1Vals |            0.11 |
# |         MaxQ1Vals |           0.633 |
# |         MinQ1Vals |           0.121 |
# |     AverageQ2Vals |           0.409 |
# |         StdQ2Vals |            0.11 |
# |         MaxQ2Vals |           0.631 |
# |         MinQ2Vals |           0.131 |
# |      AverageLogPi |          -0.538 |
# |          StdLogPi |           0.674 |
# |          MaxLogPi |            7.08 |
# |          MinLogPi |           -2.54 |
# |            LossPi |          -0.413 |
# |             LossQ |         0.00628 |
# |              Time |            18.1 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            8.22 |
# |          StdEpRet |           0.615 |
# |          MaxEpRet |             9.1 |
# |          MinEpRet |            7.05 |
# |  AverageTestEpRet |            8.71 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |            8.71 |
# |      MinTestEpRet |            8.71 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |        1.76e+03 |
# |     AverageQ1Vals |            0.79 |
# |         StdQ1Vals |           0.113 |
# |         MaxQ1Vals |            1.03 |
# |         MinQ1Vals |           0.565 |
# |     AverageQ2Vals |            0.79 |
# |         StdQ2Vals |           0.113 |
# |         MaxQ2Vals |            1.03 |
# |         MinQ2Vals |           0.566 |
# |      AverageLogPi |          -0.306 |
# |          StdLogPi |            1.12 |
# |          MaxLogPi |             8.2 |
# |          MinLogPi |            -1.8 |
# |            LossPi |          -0.795 |
# |             LossQ |         0.00609 |
# |              Time |            39.5 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            7.99 |
# |          StdEpRet |           0.342 |
# |          MaxEpRet |            8.61 |
# |          MinEpRet |            7.47 |
# |  AverageTestEpRet |            9.22 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |            9.22 |
# |      MinTestEpRet |            9.22 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |        2.64e+03 |
# |     AverageQ1Vals |            1.18 |
# |         StdQ1Vals |           0.116 |
# |         MaxQ1Vals |            1.43 |
# |         MinQ1Vals |           0.955 |
# |     AverageQ2Vals |            1.18 |
# |         StdQ2Vals |           0.116 |
# |         MaxQ2Vals |            1.43 |
# |         MinQ2Vals |           0.956 |
# |      AverageLogPi |          -0.175 |
# |          StdLogPi |            1.05 |
# |          MaxLogPi |            4.03 |
# |          MinLogPi |           -6.81 |
# |            LossPi |           -1.19 |
# |             LossQ |         0.00596 |
# |              Time |            59.7 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |            8.32 |
# |          StdEpRet |           0.331 |
# |          MaxEpRet |               9 |
# |          MinEpRet |            7.78 |
# |  AverageTestEpRet |            10.3 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |            10.3 |
# |      MinTestEpRet |            10.3 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |        3.52e+03 |
# |     AverageQ1Vals |             1.6 |
# |         StdQ1Vals |           0.128 |
# |         MaxQ1Vals |            1.87 |
# |         MinQ1Vals |            1.35 |
# |     AverageQ2Vals |             1.6 |
# |         StdQ2Vals |           0.128 |
# |         MaxQ2Vals |            1.87 |
# |         MinQ2Vals |            1.36 |
# |      AverageLogPi |           0.658 |
# |          StdLogPi |           0.962 |
# |          MaxLogPi |               2 |
# |          MinLogPi |            -9.4 |
# |            LossPi |           -1.62 |
# |             LossQ |         0.00531 |
# |              Time |            78.9 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |            8.43 |
# |          StdEpRet |           0.476 |
# |          MaxEpRet |            8.96 |
# |          MinEpRet |            7.33 |
# |  AverageTestEpRet |            10.2 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |            10.2 |
# |      MinTestEpRet |            10.2 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |         4.4e+03 |
# |     AverageQ1Vals |            2.05 |
# |         StdQ1Vals |           0.131 |
# |         MaxQ1Vals |            2.32 |
# |         MinQ1Vals |            1.79 |
# |     AverageQ2Vals |            2.05 |
# |         StdQ2Vals |           0.131 |
# |         MaxQ2Vals |            2.32 |
# |         MinQ2Vals |            1.79 |
# |      AverageLogPi |            1.23 |
# |          StdLogPi |           0.779 |
# |          MaxLogPi |            2.21 |
# |          MinLogPi |           -7.27 |
# |            LossPi |           -2.08 |
# |             LossQ |         0.00484 |
# |              Time |            99.9 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |             8.4 |
# |          StdEpRet |           0.365 |
# |          MaxEpRet |            9.09 |
# |          MinEpRet |            7.76 |
# |  AverageTestEpRet |            10.9 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |            10.9 |
# |      MinTestEpRet |            10.9 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |        5.28e+03 |
# |     AverageQ1Vals |            2.49 |
# |         StdQ1Vals |           0.127 |
# |         MaxQ1Vals |            2.75 |
# |         MinQ1Vals |            2.24 |
# |     AverageQ2Vals |            2.49 |
# |         StdQ2Vals |           0.127 |
# |         MaxQ2Vals |            2.75 |
# |         MinQ2Vals |            2.24 |
# |      AverageLogPi |             1.9 |
# |          StdLogPi |           0.745 |
# |          MaxLogPi |            2.75 |
# |          MinLogPi |           -6.89 |
# |            LossPi |           -2.52 |
# |             LossQ |         0.00457 |
# |              Time |             121 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |            8.39 |
# |          StdEpRet |           0.475 |
# |          MaxEpRet |             9.3 |
# |          MinEpRet |            7.69 |
# |  AverageTestEpRet |            10.6 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |            10.6 |
# |      MinTestEpRet |            10.6 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |        6.16e+03 |
# |     AverageQ1Vals |            2.92 |
# |         StdQ1Vals |           0.121 |
# |         MaxQ1Vals |            3.17 |
# |         MinQ1Vals |            2.67 |
# |     AverageQ2Vals |            2.92 |
# |         StdQ2Vals |           0.121 |
# |         MaxQ2Vals |            3.17 |
# |         MinQ2Vals |            2.67 |
# |      AverageLogPi |            2.29 |
# |          StdLogPi |           0.715 |
# |          MaxLogPi |            2.95 |
# |          MinLogPi |           -6.46 |
# |            LossPi |           -2.95 |
# |             LossQ |         0.00459 |
# |              Time |             140 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |            8.38 |
# |          StdEpRet |            0.48 |
# |          MaxEpRet |            9.12 |
# |          MinEpRet |            7.78 |
# |  AverageTestEpRet |            11.1 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |            11.1 |
# |      MinTestEpRet |            11.1 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |        7.04e+03 |
# |     AverageQ1Vals |            3.32 |
# |         StdQ1Vals |           0.118 |
# |         MaxQ1Vals |            3.56 |
# |         MinQ1Vals |            3.09 |
# |     AverageQ2Vals |            3.32 |
# |         StdQ2Vals |           0.118 |
# |         MaxQ2Vals |            3.56 |
# |         MinQ2Vals |            3.09 |
# |      AverageLogPi |            2.44 |
# |          StdLogPi |           0.712 |
# |          MaxLogPi |            3.11 |
# |          MinLogPi |           -7.41 |
# |            LossPi |           -3.35 |
# |             LossQ |         0.00457 |
# |              Time |             161 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |             8.4 |
# |          StdEpRet |           0.351 |
# |          MaxEpRet |            9.09 |
# |          MinEpRet |            7.96 |
# |  AverageTestEpRet |            10.8 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |            10.8 |
# |      MinTestEpRet |            10.8 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |        7.92e+03 |
# |     AverageQ1Vals |            3.72 |
# |         StdQ1Vals |           0.112 |
# |         MaxQ1Vals |            3.95 |
# |         MinQ1Vals |            3.49 |
# |     AverageQ2Vals |            3.72 |
# |         StdQ2Vals |           0.112 |
# |         MaxQ2Vals |            3.96 |
# |         MinQ2Vals |            3.48 |
# |      AverageLogPi |            2.57 |
# |          StdLogPi |           0.713 |
# |          MaxLogPi |            3.15 |
# |          MinLogPi |           -8.34 |
# |            LossPi |           -3.75 |
# |             LossQ |         0.00457 |
# |              Time |             181 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |            10.7 |
# |          StdEpRet |           0.761 |
# |          MaxEpRet |            11.5 |
# |          MinEpRet |            8.68 |
# |  AverageTestEpRet |            10.7 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |            10.7 |
# |      MinTestEpRet |            10.7 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |         8.8e+03 |
# |     AverageQ1Vals |            4.09 |
# |         StdQ1Vals |           0.107 |
# |         MaxQ1Vals |            4.31 |
# |         MinQ1Vals |            3.88 |
# |     AverageQ2Vals |            4.09 |
# |         StdQ2Vals |           0.107 |
# |         MaxQ2Vals |            4.31 |
# |         MinQ2Vals |            3.88 |
# |      AverageLogPi |            2.58 |
# |          StdLogPi |           0.708 |
# |          MaxLogPi |            3.16 |
# |          MinLogPi |           -6.14 |
# |            LossPi |           -4.12 |
# |             LossQ |         0.00463 |
# |              Time |             206 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |            10.8 |
# |          StdEpRet |           0.373 |
# |          MaxEpRet |            11.3 |
# |          MinEpRet |            9.85 |
# |  AverageTestEpRet |            11.2 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |            11.2 |
# |      MinTestEpRet |            11.2 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |        9.68e+03 |
# |     AverageQ1Vals |            4.45 |
# |         StdQ1Vals |           0.104 |
# |         MaxQ1Vals |            4.66 |
# |         MinQ1Vals |            4.24 |
# |     AverageQ2Vals |            4.45 |
# |         StdQ2Vals |           0.104 |
# |         MaxQ2Vals |            4.66 |
# |         MinQ2Vals |            4.24 |
# |      AverageLogPi |            2.59 |
# |          StdLogPi |           0.705 |
# |          MaxLogPi |            3.16 |
# |          MinLogPi |           -5.77 |
# |            LossPi |           -4.48 |
# |             LossQ |         0.00448 |
# |              Time |             230 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |            10.9 |
# |          StdEpRet |            0.33 |
# |          MaxEpRet |            11.5 |
# |          MinEpRet |            10.4 |
# |  AverageTestEpRet |            10.6 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |            10.6 |
# |      MinTestEpRet |            10.6 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |        1.06e+04 |
# |     AverageQ1Vals |             4.8 |
# |         StdQ1Vals |          0.0998 |
# |         MaxQ1Vals |               5 |
# |         MinQ1Vals |            4.59 |
# |     AverageQ2Vals |             4.8 |
# |         StdQ2Vals |          0.0998 |
# |         MaxQ2Vals |               5 |
# |         MinQ2Vals |            4.59 |
# |      AverageLogPi |            2.58 |
# |          StdLogPi |           0.716 |
# |          MaxLogPi |            3.15 |
# |          MinLogPi |           -6.11 |
# |            LossPi |           -4.82 |
# |             LossQ |         0.00445 |
# |              Time |             253 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |            10.7 |
# |          StdEpRet |           0.416 |
# |          MaxEpRet |            11.3 |
# |          MinEpRet |            10.1 |
# |  AverageTestEpRet |            10.7 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |            10.7 |
# |      MinTestEpRet |            10.7 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |        1.14e+04 |
# |     AverageQ1Vals |            5.13 |
# |         StdQ1Vals |          0.0966 |
# |         MaxQ1Vals |            5.33 |
# |         MinQ1Vals |            4.93 |
# |     AverageQ2Vals |            5.13 |
# |         StdQ2Vals |          0.0966 |
# |         MaxQ2Vals |            5.32 |
# |         MinQ2Vals |            4.93 |
# |      AverageLogPi |            2.58 |
# |          StdLogPi |            0.71 |
# |          MaxLogPi |            3.16 |
# |          MinLogPi |           -5.91 |
# |            LossPi |           -5.15 |
# |             LossQ |         0.00447 |
# |              Time |             277 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |            10.7 |
# |          StdEpRet |           0.392 |
# |          MaxEpRet |            11.5 |
# |          MinEpRet |            10.2 |
# |  AverageTestEpRet |              11 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |              11 |
# |      MinTestEpRet |              11 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |        1.23e+04 |
# |     AverageQ1Vals |            5.45 |
# |         StdQ1Vals |          0.0927 |
# |         MaxQ1Vals |            5.64 |
# |         MinQ1Vals |            5.26 |
# |     AverageQ2Vals |            5.45 |
# |         StdQ2Vals |          0.0927 |
# |         MaxQ2Vals |            5.64 |
# |         MinQ2Vals |            5.25 |
# |      AverageLogPi |            2.58 |
# |          StdLogPi |           0.711 |
# |          MaxLogPi |            3.17 |
# |          MinLogPi |           -6.73 |
# |            LossPi |           -5.47 |
# |             LossQ |         0.00451 |
# |              Time |             301 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |            10.9 |
# |          StdEpRet |           0.363 |
# |          MaxEpRet |            11.3 |
# |          MinEpRet |            10.3 |
# |  AverageTestEpRet |            10.6 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |            10.6 |
# |      MinTestEpRet |            10.6 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |        1.32e+04 |
# |     AverageQ1Vals |            5.76 |
# |         StdQ1Vals |          0.0896 |
# |         MaxQ1Vals |            5.94 |
# |         MinQ1Vals |            5.57 |
# |     AverageQ2Vals |            5.76 |
# |         StdQ2Vals |          0.0895 |
# |         MaxQ2Vals |            5.94 |
# |         MinQ2Vals |            5.57 |
# |      AverageLogPi |            2.58 |
# |          StdLogPi |           0.703 |
# |          MaxLogPi |            3.15 |
# |          MinLogPi |           -6.38 |
# |            LossPi |           -5.78 |
# |             LossQ |         0.00453 |
# |              Time |             325 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |            10.8 |
# |          StdEpRet |           0.463 |
# |          MaxEpRet |            11.5 |
# |          MinEpRet |            10.1 |
# |  AverageTestEpRet |            10.8 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |            10.8 |
# |      MinTestEpRet |            10.8 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |        1.41e+04 |
# |     AverageQ1Vals |            6.05 |
# |         StdQ1Vals |          0.0856 |
# |         MaxQ1Vals |            6.22 |
# |         MinQ1Vals |            5.87 |
# |     AverageQ2Vals |            6.05 |
# |         StdQ2Vals |          0.0856 |
# |         MaxQ2Vals |            6.22 |
# |         MinQ2Vals |            5.87 |
# |      AverageLogPi |            2.58 |
# |          StdLogPi |           0.713 |
# |          MaxLogPi |            3.14 |
# |          MinLogPi |            -7.1 |
# |            LossPi |           -6.07 |
# |             LossQ |         0.00432 |
# |              Time |             351 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |            10.9 |
# |          StdEpRet |           0.329 |
# |          MaxEpRet |            11.6 |
# |          MinEpRet |            10.3 |
# |  AverageTestEpRet |            10.4 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |            10.4 |
# |      MinTestEpRet |            10.4 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |         1.5e+04 |
# |     AverageQ1Vals |            6.34 |
# |         StdQ1Vals |          0.0823 |
# |         MaxQ1Vals |             6.5 |
# |         MinQ1Vals |            6.16 |
# |     AverageQ2Vals |            6.34 |
# |         StdQ2Vals |          0.0823 |
# |         MaxQ2Vals |             6.5 |
# |         MinQ2Vals |            6.15 |
# |      AverageLogPi |            2.59 |
# |          StdLogPi |           0.709 |
# |          MaxLogPi |            3.16 |
# |          MinLogPi |           -7.17 |
# |            LossPi |           -6.35 |
# |             LossQ |         0.00422 |
# |              Time |             375 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |            10.8 |
# |          StdEpRet |           0.311 |
# |          MaxEpRet |            11.7 |
# |          MinEpRet |            10.5 |
# |  AverageTestEpRet |            10.2 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |            10.2 |
# |      MinTestEpRet |            10.2 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |        1.58e+04 |
# |     AverageQ1Vals |            6.61 |
# |         StdQ1Vals |          0.0792 |
# |         MaxQ1Vals |            6.77 |
# |         MinQ1Vals |            6.43 |
# |     AverageQ2Vals |            6.61 |
# |         StdQ2Vals |          0.0792 |
# |         MaxQ2Vals |            6.76 |
# |         MinQ2Vals |            6.42 |
# |      AverageLogPi |             2.6 |
# |          StdLogPi |            0.71 |
# |          MaxLogPi |            3.18 |
# |          MinLogPi |           -10.7 |
# |            LossPi |           -6.62 |
# |             LossQ |         0.00429 |
# |              Time |             400 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |            10.7 |
# |          StdEpRet |           0.366 |
# |          MaxEpRet |            11.4 |
# |          MinEpRet |            9.92 |
# |  AverageTestEpRet |            9.88 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |            9.88 |
# |      MinTestEpRet |            9.88 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |        1.67e+04 |
# |     AverageQ1Vals |            6.87 |
# |         StdQ1Vals |          0.0769 |
# |         MaxQ1Vals |            7.02 |
# |         MinQ1Vals |             6.7 |
# |     AverageQ2Vals |            6.87 |
# |         StdQ2Vals |          0.0769 |
# |         MaxQ2Vals |            7.02 |
# |         MinQ2Vals |            6.69 |
# |      AverageLogPi |            2.61 |
# |          StdLogPi |           0.716 |
# |          MaxLogPi |             3.2 |
# |          MinLogPi |           -6.21 |
# |            LossPi |           -6.88 |
# |             LossQ |         0.00427 |
# |              Time |             426 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |              11 |
# |          StdEpRet |           0.311 |
# |          MaxEpRet |            11.4 |
# |          MinEpRet |            10.5 |
# |  AverageTestEpRet |            10.8 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |            10.8 |
# |      MinTestEpRet |            10.8 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |        1.76e+04 |
# |     AverageQ1Vals |            7.12 |
# |         StdQ1Vals |          0.0737 |
# |         MaxQ1Vals |            7.27 |
# |         MinQ1Vals |            6.94 |
# |     AverageQ2Vals |            7.12 |
# |         StdQ2Vals |          0.0737 |
# |         MaxQ2Vals |            7.26 |
# |         MinQ2Vals |            6.94 |
# |      AverageLogPi |            2.61 |
# |          StdLogPi |           0.707 |
# |          MaxLogPi |            3.19 |
# |          MinLogPi |           -6.56 |
# |            LossPi |           -7.13 |
# |             LossQ |          0.0042 |
# |              Time |             453 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |            10.9 |
# |          StdEpRet |           0.313 |
# |          MaxEpRet |            11.4 |
# |          MinEpRet |            10.4 |
# |  AverageTestEpRet |            10.4 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |            10.4 |
# |      MinTestEpRet |            10.4 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |        1.85e+04 |
# |     AverageQ1Vals |            7.36 |
# |         StdQ1Vals |          0.0718 |
# |         MaxQ1Vals |            7.51 |
# |         MinQ1Vals |            7.18 |
# |     AverageQ2Vals |            7.36 |
# |         StdQ2Vals |          0.0717 |
# |         MaxQ2Vals |             7.5 |
# |         MinQ2Vals |            7.18 |
# |      AverageLogPi |            2.64 |
# |          StdLogPi |           0.701 |
# |          MaxLogPi |            3.22 |
# |          MinLogPi |           -7.48 |
# |            LossPi |           -7.37 |
# |             LossQ |         0.00417 |
# |              Time |             478 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |            10.6 |
# |          StdEpRet |           0.306 |
# |          MaxEpRet |            11.2 |
# |          MinEpRet |            10.1 |
# |  AverageTestEpRet |            10.3 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |            10.3 |
# |      MinTestEpRet |            10.3 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |        1.94e+04 |
# |     AverageQ1Vals |            7.59 |
# |         StdQ1Vals |          0.0688 |
# |         MaxQ1Vals |            7.74 |
# |         MinQ1Vals |            7.42 |
# |     AverageQ2Vals |            7.59 |
# |         StdQ2Vals |          0.0688 |
# |         MaxQ2Vals |            7.73 |
# |         MinQ2Vals |            7.42 |
# |      AverageLogPi |            2.66 |
# |          StdLogPi |           0.716 |
# |          MaxLogPi |            3.24 |
# |          MinLogPi |           -6.77 |
# |            LossPi |            -7.6 |
# |             LossQ |         0.00415 |
# |              Time |             503 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |              11 |
# |          StdEpRet |           0.303 |
# |          MaxEpRet |            11.4 |
# |          MinEpRet |            10.6 |
# |  AverageTestEpRet |              11 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |              11 |
# |      MinTestEpRet |              11 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |        2.02e+04 |
# |     AverageQ1Vals |            7.81 |
# |         StdQ1Vals |          0.0658 |
# |         MaxQ1Vals |            7.95 |
# |         MinQ1Vals |            7.65 |
# |     AverageQ2Vals |            7.81 |
# |         StdQ2Vals |          0.0658 |
# |         MaxQ2Vals |            7.94 |
# |         MinQ2Vals |            7.65 |
# |      AverageLogPi |            2.65 |
# |          StdLogPi |            0.72 |
# |          MaxLogPi |            3.23 |
# |          MinLogPi |           -7.63 |
# |            LossPi |           -7.82 |
# |             LossQ |         0.00409 |
# |              Time |             527 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |            10.8 |
# |          StdEpRet |           0.329 |
# |          MaxEpRet |            11.3 |
# |          MinEpRet |            10.2 |
# |  AverageTestEpRet |            10.6 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |            10.6 |
# |      MinTestEpRet |            10.6 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |        2.11e+04 |
# |     AverageQ1Vals |            8.03 |
# |         StdQ1Vals |          0.0638 |
# |         MaxQ1Vals |            8.15 |
# |         MinQ1Vals |            7.87 |
# |     AverageQ2Vals |            8.03 |
# |         StdQ2Vals |          0.0637 |
# |         MaxQ2Vals |            8.15 |
# |         MinQ2Vals |            7.86 |
# |      AverageLogPi |            2.65 |
# |          StdLogPi |            0.71 |
# |          MaxLogPi |            3.24 |
# |          MinLogPi |           -6.59 |
# |            LossPi |           -8.04 |
# |             LossQ |         0.00409 |
# |              Time |             552 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |            11.1 |
# |          StdEpRet |           0.282 |
# |          MaxEpRet |            11.7 |
# |          MinEpRet |            10.7 |
# |  AverageTestEpRet |            10.7 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |            10.7 |
# |      MinTestEpRet |            10.7 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |         2.2e+04 |
# |     AverageQ1Vals |            8.23 |
# |         StdQ1Vals |          0.0618 |
# |         MaxQ1Vals |            8.35 |
# |         MinQ1Vals |            8.08 |
# |     AverageQ2Vals |            8.23 |
# |         StdQ2Vals |          0.0617 |
# |         MaxQ2Vals |            8.35 |
# |         MinQ2Vals |            8.08 |
# |      AverageLogPi |            2.61 |
# |          StdLogPi |           0.699 |
# |          MaxLogPi |            3.21 |
# |          MinLogPi |           -6.27 |
# |            LossPi |           -8.24 |
# |             LossQ |           0.004 |
# |              Time |             576 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |            10.8 |
# |          StdEpRet |           0.319 |
# |          MaxEpRet |            11.2 |
# |          MinEpRet |            9.96 |
# |  AverageTestEpRet |            10.8 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |            10.8 |
# |      MinTestEpRet |            10.8 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |        2.29e+04 |
# |     AverageQ1Vals |            8.43 |
# |         StdQ1Vals |           0.059 |
# |         MaxQ1Vals |            8.55 |
# |         MinQ1Vals |            8.28 |
# |     AverageQ2Vals |            8.43 |
# |         StdQ2Vals |           0.059 |
# |         MaxQ2Vals |            8.55 |
# |         MinQ2Vals |            8.28 |
# |      AverageLogPi |            2.56 |
# |          StdLogPi |           0.713 |
# |          MaxLogPi |            3.16 |
# |          MinLogPi |           -6.25 |
# |            LossPi |           -8.44 |
# |             LossQ |         0.00395 |
# |              Time |             600 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |            10.8 |
# |          StdEpRet |           0.467 |
# |          MaxEpRet |            11.9 |
# |          MinEpRet |            10.1 |
# |  AverageTestEpRet |            10.5 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |            10.5 |
# |      MinTestEpRet |            10.5 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |        2.38e+04 |
# |     AverageQ1Vals |            8.62 |
# |         StdQ1Vals |          0.0569 |
# |         MaxQ1Vals |            8.73 |
# |         MinQ1Vals |            8.46 |
# |     AverageQ2Vals |            8.62 |
# |         StdQ2Vals |          0.0569 |
# |         MaxQ2Vals |            8.73 |
# |         MinQ2Vals |            8.47 |
# |      AverageLogPi |            2.51 |
# |          StdLogPi |           0.715 |
# |          MaxLogPi |            3.11 |
# |          MinLogPi |           -6.44 |
# |            LossPi |           -8.63 |
# |             LossQ |         0.00393 |
# |              Time |             624 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |            11.1 |
# |          StdEpRet |           0.338 |
# |          MaxEpRet |            11.7 |
# |          MinEpRet |            10.5 |
# |  AverageTestEpRet |              11 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |              11 |
# |      MinTestEpRet |              11 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |        2.46e+04 |
# |     AverageQ1Vals |             8.8 |
# |         StdQ1Vals |          0.0549 |
# |         MaxQ1Vals |            8.91 |
# |         MinQ1Vals |            8.66 |
# |     AverageQ2Vals |             8.8 |
# |         StdQ2Vals |          0.0549 |
# |         MaxQ2Vals |            8.91 |
# |         MinQ2Vals |            8.65 |
# |      AverageLogPi |            2.48 |
# |          StdLogPi |           0.711 |
# |          MaxLogPi |             3.1 |
# |          MinLogPi |           -5.74 |
# |            LossPi |           -8.81 |
# |             LossQ |         0.00396 |
# |              Time |             649 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |            10.8 |
# |          StdEpRet |           0.381 |
# |          MaxEpRet |            11.4 |
# |          MinEpRet |            10.2 |
# |  AverageTestEpRet |            10.6 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |            10.6 |
# |      MinTestEpRet |            10.6 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |        2.55e+04 |
# |     AverageQ1Vals |            8.97 |
# |         StdQ1Vals |          0.0527 |
# |         MaxQ1Vals |            9.08 |
# |         MinQ1Vals |            8.83 |
# |     AverageQ2Vals |            8.97 |
# |         StdQ2Vals |          0.0526 |
# |         MaxQ2Vals |            9.08 |
# |         MinQ2Vals |            8.82 |
# |      AverageLogPi |            2.44 |
# |          StdLogPi |           0.709 |
# |          MaxLogPi |            3.04 |
# |          MinLogPi |           -5.64 |
# |            LossPi |           -8.98 |
# |             LossQ |         0.00397 |
# |              Time |             674 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |            10.6 |
# |          StdEpRet |           0.424 |
# |          MaxEpRet |            11.4 |
# |          MinEpRet |            9.92 |
# |  AverageTestEpRet |            11.3 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |            11.3 |
# |      MinTestEpRet |            11.3 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |        2.64e+04 |
# |     AverageQ1Vals |            9.14 |
# |         StdQ1Vals |          0.0511 |
# |         MaxQ1Vals |            9.24 |
# |         MinQ1Vals |               9 |
# |     AverageQ2Vals |            9.14 |
# |         StdQ2Vals |           0.051 |
# |         MaxQ2Vals |            9.24 |
# |         MinQ2Vals |            9.01 |
# |      AverageLogPi |            2.42 |
# |          StdLogPi |           0.711 |
# |          MaxLogPi |            3.03 |
# |          MinLogPi |            -6.1 |
# |            LossPi |           -9.15 |
# |             LossQ |         0.00389 |
# |              Time |             697 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |              11 |
# |          StdEpRet |            0.33 |
# |          MaxEpRet |            11.4 |
# |          MinEpRet |            10.4 |
# |  AverageTestEpRet |            11.3 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |            11.3 |
# |      MinTestEpRet |            11.3 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |        2.73e+04 |
# |     AverageQ1Vals |             9.3 |
# |         StdQ1Vals |           0.049 |
# |         MaxQ1Vals |             9.4 |
# |         MinQ1Vals |            9.17 |
# |     AverageQ2Vals |             9.3 |
# |         StdQ2Vals |           0.049 |
# |         MaxQ2Vals |             9.4 |
# |         MinQ2Vals |            9.17 |
# |      AverageLogPi |            2.38 |
# |          StdLogPi |           0.718 |
# |          MaxLogPi |            2.99 |
# |          MinLogPi |           -6.03 |
# |            LossPi |           -9.31 |
# |             LossQ |         0.00389 |
# |              Time |             721 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |            10.9 |
# |          StdEpRet |           0.396 |
# |          MaxEpRet |            11.8 |
# |          MinEpRet |            10.4 |
# |  AverageTestEpRet |            10.3 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |            10.3 |
# |      MinTestEpRet |            10.3 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |        2.82e+04 |
# |     AverageQ1Vals |            9.46 |
# |         StdQ1Vals |          0.0468 |
# |         MaxQ1Vals |            9.55 |
# |         MinQ1Vals |            9.33 |
# |     AverageQ2Vals |            9.46 |
# |         StdQ2Vals |          0.0467 |
# |         MaxQ2Vals |            9.55 |
# |         MinQ2Vals |            9.32 |
# |      AverageLogPi |            2.35 |
# |          StdLogPi |           0.721 |
# |          MaxLogPi |            2.97 |
# |          MinLogPi |           -6.24 |
# |            LossPi |           -9.46 |
# |             LossQ |         0.00389 |
# |              Time |             746 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |            10.9 |
# |          StdEpRet |           0.232 |
# |          MaxEpRet |            11.3 |
# |          MinEpRet |            10.5 |
# |  AverageTestEpRet |            10.8 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |            10.8 |
# |      MinTestEpRet |            10.8 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |         2.9e+04 |
# |     AverageQ1Vals |             9.6 |
# |         StdQ1Vals |          0.0458 |
# |         MaxQ1Vals |             9.7 |
# |         MinQ1Vals |            9.47 |
# |     AverageQ2Vals |             9.6 |
# |         StdQ2Vals |          0.0458 |
# |         MaxQ2Vals |             9.7 |
# |         MinQ2Vals |            9.47 |
# |      AverageLogPi |            2.31 |
# |          StdLogPi |           0.708 |
# |          MaxLogPi |            2.92 |
# |          MinLogPi |           -7.29 |
# |            LossPi |           -9.61 |
# |             LossQ |         0.00384 |
# |              Time |             771 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |            10.9 |
# |          StdEpRet |           0.347 |
# |          MaxEpRet |            11.4 |
# |          MinEpRet |              10 |
# |  AverageTestEpRet |            10.9 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |            10.9 |
# |      MinTestEpRet |            10.9 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |        2.99e+04 |
# |     AverageQ1Vals |            9.75 |
# |         StdQ1Vals |          0.0445 |
# |         MaxQ1Vals |            9.84 |
# |         MinQ1Vals |            9.61 |
# |     AverageQ2Vals |            9.75 |
# |         StdQ2Vals |          0.0444 |
# |         MaxQ2Vals |            9.84 |
# |         MinQ2Vals |            9.61 |
# |      AverageLogPi |            2.25 |
# |          StdLogPi |            0.72 |
# |          MaxLogPi |            2.86 |
# |          MinLogPi |           -7.91 |
# |            LossPi |           -9.75 |
# |             LossQ |          0.0038 |
# |              Time |             794 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |            10.8 |
# |          StdEpRet |           0.291 |
# |          MaxEpRet |            11.2 |
# |          MinEpRet |            10.1 |
# |  AverageTestEpRet |            10.4 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |            10.4 |
# |      MinTestEpRet |            10.4 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |        3.08e+04 |
# |     AverageQ1Vals |            9.88 |
# |         StdQ1Vals |          0.0428 |
# |         MaxQ1Vals |            9.97 |
# |         MinQ1Vals |            9.75 |
# |     AverageQ2Vals |            9.88 |
# |         StdQ2Vals |          0.0428 |
# |         MaxQ2Vals |            9.96 |
# |         MinQ2Vals |            9.75 |
# |      AverageLogPi |            2.22 |
# |          StdLogPi |           0.717 |
# |          MaxLogPi |            2.83 |
# |          MinLogPi |           -6.48 |
# |            LossPi |           -9.89 |
# |             LossQ |         0.00377 |
# |              Time |             818 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |              11 |
# |          StdEpRet |           0.352 |
# |          MaxEpRet |            11.6 |
# |          MinEpRet |            10.5 |
# |  AverageTestEpRet |            10.7 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |            10.7 |
# |      MinTestEpRet |            10.7 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |        3.17e+04 |
# |     AverageQ1Vals |              10 |
# |         StdQ1Vals |           0.041 |
# |         MaxQ1Vals |            10.1 |
# |         MinQ1Vals |            9.89 |
# |     AverageQ2Vals |              10 |
# |         StdQ2Vals |           0.041 |
# |         MaxQ2Vals |            10.1 |
# |         MinQ2Vals |            9.89 |
# |      AverageLogPi |            2.25 |
# |          StdLogPi |           0.711 |
# |          MaxLogPi |            2.84 |
# |          MinLogPi |           -5.88 |
# |            LossPi |             -10 |
# |             LossQ |         0.00379 |
# |              Time |             846 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |            10.8 |
# |          StdEpRet |            0.32 |
# |          MaxEpRet |            11.2 |
# |          MinEpRet |              10 |
# |  AverageTestEpRet |            10.3 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |            10.3 |
# |      MinTestEpRet |            10.3 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |        3.26e+04 |
# |     AverageQ1Vals |            10.1 |
# |         StdQ1Vals |          0.0399 |
# |         MaxQ1Vals |            10.2 |
# |         MinQ1Vals |              10 |
# |     AverageQ2Vals |            10.1 |
# |         StdQ2Vals |          0.0398 |
# |         MaxQ2Vals |            10.2 |
# |         MinQ2Vals |              10 |
# |      AverageLogPi |            2.23 |
# |          StdLogPi |           0.716 |
# |          MaxLogPi |            2.84 |
# |          MinLogPi |           -10.3 |
# |            LossPi |           -10.1 |
# |             LossQ |         0.00378 |
# |              Time |             869 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |            10.9 |
# |          StdEpRet |           0.483 |
# |          MaxEpRet |            11.5 |
# |          MinEpRet |              10 |
# |  AverageTestEpRet |            10.1 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |            10.1 |
# |      MinTestEpRet |            10.1 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |        3.34e+04 |
# |     AverageQ1Vals |            10.3 |
# |         StdQ1Vals |          0.0381 |
# |         MaxQ1Vals |            10.3 |
# |         MinQ1Vals |            10.1 |
# |     AverageQ2Vals |            10.3 |
# |         StdQ2Vals |          0.0381 |
# |         MaxQ2Vals |            10.3 |
# |         MinQ2Vals |            10.1 |
# |      AverageLogPi |            2.18 |
# |          StdLogPi |           0.715 |
# |          MaxLogPi |            2.76 |
# |          MinLogPi |           -6.22 |
# |            LossPi |           -10.3 |
# |             LossQ |         0.00374 |
# |              Time |             895 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |            10.9 |
# |          StdEpRet |           0.452 |
# |          MaxEpRet |            11.7 |
# |          MinEpRet |            10.1 |
# |  AverageTestEpRet |            11.1 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |            11.1 |
# |      MinTestEpRet |            11.1 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |        3.43e+04 |
# |     AverageQ1Vals |            10.4 |
# |         StdQ1Vals |          0.0377 |
# |         MaxQ1Vals |            10.5 |
# |         MinQ1Vals |            10.3 |
# ...
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |            10.6 |
# |      MinTestEpRet |            10.6 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |        7.83e+04 |
# |     AverageQ1Vals |            12.8 |
# |         StdQ1Vals |           0.013 |
# |         MaxQ1Vals |            12.8 |
# |         MinQ1Vals |            12.7 |
# |     AverageQ2Vals |            12.8 |
# |         StdQ2Vals |           0.013 |
# |         MaxQ2Vals |            12.8 |
# |         MinQ2Vals |            12.7 |
# |      AverageLogPi |            2.01 |
# |          StdLogPi |           0.712 |
# |          MaxLogPi |            2.61 |
# |          MinLogPi |           -9.14 |
# |            LossPi |           -12.8 |
# |             LossQ |         0.00349 |
# |              Time |        2.14e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              90 |
# |      AverageEpRet |            10.9 |
# |          StdEpRet |            0.24 |
# |          MaxEpRet |            11.1 |
# |          MinEpRet |            10.3 |
# |  AverageTestEpRet |            11.5 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |            11.5 |
# |      MinTestEpRet |            11.5 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |        7.92e+04 |
# |     AverageQ1Vals |            12.8 |
# |         StdQ1Vals |           0.013 |
# |         MaxQ1Vals |            12.8 |
# |         MinQ1Vals |            12.7 |
# |     AverageQ2Vals |            12.8 |
# |         StdQ2Vals |           0.013 |
# |         MaxQ2Vals |            12.8 |
# |         MinQ2Vals |            12.7 |
# |      AverageLogPi |            2.01 |
# |          StdLogPi |           0.722 |
# |          MaxLogPi |            2.63 |
# |          MinLogPi |           -8.53 |
# |            LossPi |           -12.8 |
# |             LossQ |          0.0035 |
# |              Time |        2.17e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              91 |
# |      AverageEpRet |            10.7 |
# |          StdEpRet |            0.23 |
# |          MaxEpRet |              11 |
# |          MinEpRet |            10.4 |
# |  AverageTestEpRet |              11 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |              11 |
# |      MinTestEpRet |              11 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |        8.01e+04 |
# |     AverageQ1Vals |            12.8 |
# |         StdQ1Vals |          0.0134 |
# |         MaxQ1Vals |            12.8 |
# |         MinQ1Vals |            12.7 |
# |     AverageQ2Vals |            12.8 |
# |         StdQ2Vals |          0.0133 |
# |         MaxQ2Vals |            12.8 |
# |         MinQ2Vals |            12.7 |
# |      AverageLogPi |            2.07 |
# |          StdLogPi |           0.719 |
# |          MaxLogPi |            2.69 |
# |          MinLogPi |           -7.25 |
# |            LossPi |           -12.8 |
# |             LossQ |          0.0035 |
# |              Time |        2.19e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              92 |
# |      AverageEpRet |            10.9 |
# |          StdEpRet |           0.411 |
# |          MaxEpRet |            11.5 |
# |          MinEpRet |            10.2 |
# |  AverageTestEpRet |            11.2 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |            11.2 |
# |      MinTestEpRet |            11.2 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |         8.1e+04 |
# |     AverageQ1Vals |            12.8 |
# |         StdQ1Vals |          0.0129 |
# |         MaxQ1Vals |            12.8 |
# |         MinQ1Vals |            12.7 |
# |     AverageQ2Vals |            12.8 |
# |         StdQ2Vals |          0.0129 |
# |         MaxQ2Vals |            12.8 |
# |         MinQ2Vals |            12.7 |
# |      AverageLogPi |            2.05 |
# |          StdLogPi |           0.707 |
# |          MaxLogPi |            2.65 |
# |          MinLogPi |           -5.94 |
# |            LossPi |           -12.8 |
# |             LossQ |         0.00348 |
# |              Time |        2.22e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              93 |
# |      AverageEpRet |            10.8 |
# |          StdEpRet |           0.334 |
# |          MaxEpRet |            11.3 |
# |          MinEpRet |            10.2 |
# |  AverageTestEpRet |            11.3 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |            11.3 |
# |      MinTestEpRet |            11.3 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |        8.18e+04 |
# |     AverageQ1Vals |            12.8 |
# |         StdQ1Vals |          0.0128 |
# |         MaxQ1Vals |            12.9 |
# |         MinQ1Vals |            12.7 |
# |     AverageQ2Vals |            12.8 |
# |         StdQ2Vals |          0.0128 |
# |         MaxQ2Vals |            12.9 |
# |         MinQ2Vals |            12.7 |
# |      AverageLogPi |            2.08 |
# |          StdLogPi |           0.704 |
# |          MaxLogPi |            2.68 |
# |          MinLogPi |           -7.76 |
# |            LossPi |           -12.8 |
# |             LossQ |         0.00351 |
# |              Time |        2.24e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              94 |
# |      AverageEpRet |            10.7 |
# |          StdEpRet |            0.28 |
# |          MaxEpRet |            11.1 |
# |          MinEpRet |            10.2 |
# |  AverageTestEpRet |            10.1 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |            10.1 |
# |      MinTestEpRet |            10.1 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |        8.27e+04 |
# |     AverageQ1Vals |            12.8 |
# |         StdQ1Vals |          0.0127 |
# |         MaxQ1Vals |            12.9 |
# |         MinQ1Vals |            12.8 |
# |     AverageQ2Vals |            12.8 |
# |         StdQ2Vals |          0.0127 |
# |         MaxQ2Vals |            12.9 |
# |         MinQ2Vals |            12.8 |
# |      AverageLogPi |            2.02 |
# |          StdLogPi |           0.708 |
# |          MaxLogPi |            2.64 |
# |          MinLogPi |            -8.4 |
# |            LossPi |           -12.8 |
# |             LossQ |         0.00351 |
# |              Time |        2.26e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              95 |
# |      AverageEpRet |            10.8 |
# |          StdEpRet |           0.373 |
# |          MaxEpRet |            11.4 |
# |          MinEpRet |            10.2 |
# |  AverageTestEpRet |            11.2 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |            11.2 |
# |      MinTestEpRet |            11.2 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |        8.36e+04 |
# |     AverageQ1Vals |            12.8 |
# |         StdQ1Vals |          0.0127 |
# |         MaxQ1Vals |            12.9 |
# |         MinQ1Vals |            12.8 |
# |     AverageQ2Vals |            12.8 |
# |         StdQ2Vals |          0.0127 |
# |         MaxQ2Vals |            12.9 |
# |         MinQ2Vals |            12.8 |
# |      AverageLogPi |            1.98 |
# |          StdLogPi |           0.713 |
# |          MaxLogPi |             2.6 |
# |          MinLogPi |           -7.98 |
# |            LossPi |           -12.8 |
# |             LossQ |          0.0035 |
# |              Time |        2.29e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              96 |
# |      AverageEpRet |              11 |
# |          StdEpRet |           0.408 |
# |          MaxEpRet |            11.6 |
# |          MinEpRet |            10.4 |
# |  AverageTestEpRet |              11 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |              11 |
# |      MinTestEpRet |              11 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |        8.45e+04 |
# |     AverageQ1Vals |            12.9 |
# |         StdQ1Vals |          0.0123 |
# |         MaxQ1Vals |            12.9 |
# |         MinQ1Vals |            12.8 |
# |     AverageQ2Vals |            12.9 |
# |         StdQ2Vals |          0.0123 |
# |         MaxQ2Vals |            12.9 |
# |         MinQ2Vals |            12.8 |
# |      AverageLogPi |            2.03 |
# |          StdLogPi |           0.716 |
# |          MaxLogPi |            2.68 |
# |          MinLogPi |           -8.11 |
# |            LossPi |           -12.9 |
# |             LossQ |         0.00345 |
# |              Time |        2.31e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              97 |
# |      AverageEpRet |            10.7 |
# |          StdEpRet |           0.345 |
# |          MaxEpRet |            11.4 |
# |          MinEpRet |            10.2 |
# |  AverageTestEpRet |            10.4 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |            10.4 |
# |      MinTestEpRet |            10.4 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |        8.54e+04 |
# |     AverageQ1Vals |            12.9 |
# |         StdQ1Vals |          0.0125 |
# |         MaxQ1Vals |            12.9 |
# |         MinQ1Vals |            12.8 |
# |     AverageQ2Vals |            12.9 |
# |         StdQ2Vals |          0.0125 |
# |         MaxQ2Vals |            12.9 |
# |         MinQ2Vals |            12.8 |
# |      AverageLogPi |            2.03 |
# |          StdLogPi |           0.714 |
# |          MaxLogPi |            2.63 |
# |          MinLogPi |           -7.87 |
# |            LossPi |           -12.9 |
# |             LossQ |         0.00353 |
# |              Time |        2.33e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              98 |
# |      AverageEpRet |              11 |
# |          StdEpRet |           0.335 |
# |          MaxEpRet |            11.5 |
# |          MinEpRet |            10.3 |
# |  AverageTestEpRet |            10.8 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |            10.8 |
# |      MinTestEpRet |            10.8 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |        8.62e+04 |
# |     AverageQ1Vals |            12.9 |
# |         StdQ1Vals |          0.0124 |
# |         MaxQ1Vals |            12.9 |
# |         MinQ1Vals |            12.8 |
# |     AverageQ2Vals |            12.9 |
# |         StdQ2Vals |          0.0124 |
# |         MaxQ2Vals |            12.9 |
# |         MinQ2Vals |            12.8 |
# |      AverageLogPi |            2.02 |
# |          StdLogPi |           0.713 |
# |          MaxLogPi |            2.62 |
# |          MinLogPi |           -6.29 |
# |            LossPi |           -12.9 |
# |             LossQ |         0.00352 |
# |              Time |        2.36e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              99 |
# |      AverageEpRet |            10.8 |
# |          StdEpRet |           0.276 |
# |          MaxEpRet |              11 |
# |          MinEpRet |            10.2 |
# |  AverageTestEpRet |            10.8 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |            10.8 |
# |      MinTestEpRet |            10.8 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |        8.71e+04 |
# |     AverageQ1Vals |            12.9 |
# |         StdQ1Vals |          0.0122 |
# |         MaxQ1Vals |            12.9 |
# |         MinQ1Vals |            12.8 |
# |     AverageQ2Vals |            12.9 |
# |         StdQ2Vals |          0.0122 |
# |         MaxQ2Vals |            12.9 |
# |         MinQ2Vals |            12.8 |
# |      AverageLogPi |            2.02 |
# |          StdLogPi |            0.71 |
# |          MaxLogPi |            2.61 |
# |          MinLogPi |           -6.63 |
# |            LossPi |           -12.9 |
# |             LossQ |         0.00343 |
# |              Time |        2.38e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             100 |
# |      AverageEpRet |            10.8 |
# |          StdEpRet |           0.283 |
# |          MaxEpRet |            11.2 |
# |          MinEpRet |            10.3 |
# |  AverageTestEpRet |              11 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |              11 |
# |      MinTestEpRet |              11 |
# |             EpLen |              80 |
# |         TestEpLen |              80 |
# | TotalEnvInteracts |         8.8e+04 |
# |     AverageQ1Vals |            12.9 |
# |         StdQ1Vals |          0.0126 |
# |         MaxQ1Vals |            12.9 |
# |         MinQ1Vals |            12.8 |
# |     AverageQ2Vals |            12.9 |
# |         StdQ2Vals |          0.0125 |
# |         MaxQ2Vals |            12.9 |
# |         MinQ2Vals |            12.8 |
# |      AverageLogPi |            2.04 |
# |          StdLogPi |           0.712 |
# |          MaxLogPi |            2.63 |
# |          MinLogPi |              -7 |
# |            LossPi |           -12.9 |
# |             LossQ |         0.00349 |
# |              Time |         2.4e+03 |
# ---------------------------------------
# Widget Javascript not detected.  It may not be installed or enabled properly. Reconnecting the current kernel may help.
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Alpha</td><td>▁▁▁▁▁▁▂▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇██</td></tr><tr><td>EpLen</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>EpRet</td><td>▃▁▂▁▆▆▆▆▆▇▆▇▆▇█▆▇▅▇▆▇▆▆▇▆█▆▆▆▆▆▆▇▇▆▆▇▆▆▇</td></tr><tr><td>LossAlpha</td><td>▁▃▆▇███████▇▇▇▇▇▇▆▆▆▇▆▆▆▆▇▆▆▆▆▆▆▆▆▆▆▆▆▆▆</td></tr><tr><td>LossPi</td><td>█▇▇▆▆▅▅▄▄▄▄▃▃▃▃▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>LossQ</td><td>▇█▃▂▄▅▃▂▄▄▄▃▄▂▃▂▄▂▃▃▂▃▃▂▂▃▂▃▃▂▂▂▂▂▁▂▃▂▄▂</td></tr><tr><td>TestActions</td><td>█▁▂▂▂▃▃▃▃▃▃▃▂▃▃▃▂▂▂▂▃▃▃▃▂▃▃▃▃▂▂▂▂▂▃▃▃▃▂▃</td></tr><tr><td>TestEpRet</td><td>▁▅▇██▇▇▆▇▇▇▇█▇▇█▇▇████▆█▆▇▇▇▇▇▇▇██▇▇█▆▇▇</td></tr><tr><td>actions</td><td>▆█▂▇▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Alpha</td><td>0.0021</td></tr><tr><td>EpLen</td><td>80</td></tr><tr><td>EpRet</td><td>10.29181</td></tr><tr><td>LossAlpha</td><td>6.4201</td></tr><tr><td>LossPi</td><td>-12.88845</td></tr><tr><td>LossQ</td><td>0.00293</td></tr><tr><td>TestActions</td><td>-0.70368</td></tr><tr><td>TestEpRet</td><td>11.0245</td></tr><tr><td>actions</td><td>-0.68359</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">upbeat-deluge-118</strong> at: <a href='https://wandb.ai/julii/test_simple/runs/80p9d7sm' target="_blank">https://wandb.ai/julii/test_simple/runs/80p9d7sm</a><br/> View project at: <a href='https://wandb.ai/julii/test_simple' target="_blank">https://wandb.ai/julii/test_simple</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240723_201316-80p9d7sm/logs</code>
# The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
