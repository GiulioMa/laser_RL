# %%
import core_FPGA as core
import torch
import numpy as np
from utils import create_input_tensor
import matplotlib.pyplot as plt

scale = 1/32000.

# Initialize model and set device
hidden_sizes = [core.N_HIDDEN_1, core.N_HIDDEN_2]
device = torch.device('cpu')
model = core.Digital_twin(core.N_INPUT, 1, hidden_sizes, scale, device).to(device)

# Matrix operations
def matrix_multiply_sw(A, B):
  return np.dot(A, B).astype(np.int64)

def matrix_add_sw(A, B):
  return (A + B).astype(np.int64)

def apply_relu_sw(matrix):
  return np.maximum(matrix, 0).astype(np.int64)

# Forward Pass
def forward_pass_sw(X, W1, b1, W2, b2, W3, b3):
  A1 = apply_relu_sw(matrix_add_sw(matrix_multiply_sw(W1, X), b1))
  A2 = apply_relu_sw(matrix_add_sw(matrix_multiply_sw(W2, A1), b2))
  return matrix_add_sw(matrix_multiply_sw(W3, A2), b3).astype(np.int64)

# Function to calculate error statistics
def calculate_error_stats(error_list):
  error_array = np.array(error_list)
  return {
      'max': np.max(error_array),
      'min': np.min(error_array),
      'mean': np.mean(error_array),
      'median': np.median(error_array),
      'std': np.std(error_array),
      '25th_percentile': np.percentile(error_array, 25),
      '75th_percentile': np.percentile(error_array, 75),
  }

# Initialize variables
N_RUNS = 100
errors = []

# Run inference once to cache quantized weights and biases
in_float = create_input_tensor(core.N_INPUT, scale, device)
model.eval()
out_brevitas = model(in_float)

# Extract and convert weights and biases to numpy arrays
W1_sw = model.fc1.quant_weight().int().cpu().numpy().astype(np.int64)
b1_sw = model.fc1.quant_bias().int().cpu().numpy().astype(np.int64).reshape(-1, 1)
W2_sw = model.fc2.quant_weight().int().cpu().numpy().astype(np.int64)
b2_sw = model.fc2.quant_bias().int().cpu().numpy().astype(np.int64).reshape(-1, 1)
W3_sw = model.fc3.quant_weight().int().cpu().numpy().astype(np.int64)
b3_sw = model.fc3.quant_bias().int().cpu().numpy().astype(np.int64).reshape(-1, 1)

# Perform multiple runs to compare results
for _ in range(N_RUNS):
  in_float = create_input_tensor(core.N_INPUT, scale, device)
  try:
      out_brevitas = model(in_float)
      out_brevitas_int = out_brevitas.int().cpu().numpy().astype(np.int64)
  except Exception as e:
      print(f"Error occurred: {e}")
      print(f"Input tensor: {in_float}")
      continue

  X_sw = in_float.divide(scale).view(-1, 1).cpu().numpy().astype(np.int64)
  Y_pred_64 = forward_pass_sw(X_sw, W1_sw, b1_sw, W2_sw, b2_sw, W3_sw, b3_sw)

  # Calculate and append errors for both outputs
  for i in range(2):
      error = (out_brevitas_int[:, i] - Y_pred_64[i, 0]) / Y_pred_64[i, 0]
      errors.append(error[0])

# Calculate and print error statistics
stats = calculate_error_stats(errors)
print("Error Statistics:")
for stat_name, stat_value in stats.items():
  print(f"  {stat_name.capitalize()}: {stat_value} %")

# Plot error distribution
plt.figure(figsize=(10, 5))
plt.hist(errors, bins=50, edgecolor='black')
plt.title('Error Distribution')
plt.xlabel('Error (%)')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()
# Out:
# Error Statistics:
#   Max: 0.0004979354494437639 %
#   Min: -1.2770435977666185e-05 %
#   Mean: 3.3127612346676907e-06 %
#   Median: 6.655962881087833e-08 %
#   Std: 3.580823796263372e-05 %
#   25th_percentile: -1.4073502718795229e-08 %
#   75th_percentile: 2.3010038342493805e-07 %

# %%
def find_optimal_scale(min_scale=1/100000, max_scale=1, tolerance=1e-6, max_iterations=50):
  def run_experiment(scale):
      print(f"\nRunning experiment with scale: {scale:.8f}")
      
      # Initialize model and set device
      hidden_sizes = [core.N_HIDDEN_1, core.N_HIDDEN_2]
      device = torch.device('cpu')
      model = core.Digital_twin(core.N_INPUT, 1, hidden_sizes, scale, device).to(device)

      N_RUNS = 1000
      errors = []

      # Run inference once to cache quantized weights and biases
      in_float = create_input_tensor(core.N_INPUT, scale, device)
      model.eval()
      out_brevitas = model(in_float)

      # Extract and convert weights and biases to numpy arrays
      W1_sw = model.fc1.quant_weight().int().cpu().numpy().astype(np.int64)
      b1_sw = model.fc1.quant_bias().int().cpu().numpy().astype(np.int64).reshape(-1, 1)
      W2_sw = model.fc2.quant_weight().int().cpu().numpy().astype(np.int64)
      b2_sw = model.fc2.quant_bias().int().cpu().numpy().astype(np.int64).reshape(-1, 1)
      W3_sw = model.fc3.quant_weight().int().cpu().numpy().astype(np.int64)
      b3_sw = model.fc3.quant_bias().int().cpu().numpy().astype(np.int64).reshape(-1, 1)

      for run in range(N_RUNS):
          in_float = create_input_tensor(core.N_INPUT, scale, device)
          try:
              out_brevitas = model(in_float)
              out_brevitas_int = out_brevitas.int().cpu().numpy().astype(np.int64)
          except Exception as e:
              print(f"Error occurred in run {run + 1}: {e}")
              print(f"Input tensor: {in_float}")
              continue

          X_sw = in_float.divide(scale).view(-1, 1).cpu().numpy().astype(np.int64)
          Y_pred_64 = forward_pass_sw(X_sw, W1_sw, b1_sw, W2_sw, b2_sw, W3_sw, b3_sw)

          for i in range(2):
              error = (out_brevitas_int[:, i] - Y_pred_64[i, 0]) / Y_pred_64[i, 0]
              errors.append(error[0])

          if (run + 1) % 100 == 0:
              print(f"Completed {run + 1} runs")

      median_error = np.median(errors)
      print(f"Experiment results - Median error: {median_error:.8f} %")
      return median_error

  print("Starting optimization process to find the optimal scale")
  print(f"Search range: [{min_scale}, {max_scale}]")
  print(f"Tolerance: {tolerance}")
  print(f"Maximum iterations: {max_iterations}")

  left, right = min_scale, max_scale
  iteration = 0

  while right - left > tolerance and iteration < max_iterations:
      mid1 = left + (right - left) / 3
      mid2 = right - (right - left) / 3

      print(f"\nIteration {iteration + 1}")
      error1 = run_experiment(mid1)
      error2 = run_experiment(mid2)

      if abs(error1) < abs(error2):
          right = mid2
          print(f"Narrowing search range to [{left:.8f}, {right:.8f}]")
      else:
          left = mid1
          print(f"Narrowing search range to [{left:.8f}, {right:.8f}]")

      iteration += 1

  optimal_scale = (left + right) / 2
  print("\nOptimization complete")
  print(f"Optimal scale found: {optimal_scale:.8f}")
  
  print("\nRunning final experiment with optimal scale")
  optimal_error = run_experiment(optimal_scale)

  return optimal_scale, optimal_error

# Run the optimization
optimal_scale, optimal_error = find_optimal_scale()
print(f"\nFinal results:")
print(f"Optimal scale: {optimal_scale:.8f}")
print(f"Optimal median error: {optimal_error:.8f} %")
# Out:
# Starting optimization process to find the optimal scale
# Search range: [1e-05, 1]
# Tolerance: 1e-06
# Maximum iterations: 50
#
# Iteration 1
#
# Running experiment with scale: 0.33334000
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: -0.00000003 %
#
# Running experiment with scale: 0.66667000
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: 0.00000009 %
# Narrowing search range to [0.00001000, 0.66667000]
#
# Iteration 2
#
# Running experiment with scale: 0.22223000
# Error occurred in run 85: QuantTensor not valid.
# Input tensor: tensor([[ 843.8073, 2878.9897]])
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: 0.00000001 %
#
# Running experiment with scale: 0.44445000
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: 0.00000009 %
# Narrowing search range to [0.00001000, 0.44445000]
#
# Iteration 3
#
# Running experiment with scale: 0.14815667
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: 0.00000003 %
#
# Running experiment with scale: 0.29630333
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: 0.00000005 %
# Narrowing search range to [0.00001000, 0.29630333]
#
# Iteration 4
#
# Running experiment with scale: 0.09877444
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: -0.00000008 %
#
# Running experiment with scale: 0.19753889
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: -0.00000004 %
# Narrowing search range to [0.09877444, 0.29630333]
#
# Iteration 5
#
# Running experiment with scale: 0.16461741
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: -0.00000005 %
#
# Running experiment with scale: 0.23046037
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: 0.00000004 %
# Narrowing search range to [0.16461741, 0.29630333]
#
# Iteration 6
#
# Running experiment with scale: 0.20851272
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: -0.00000010 %
#
# Running experiment with scale: 0.25240802
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Error occurred in run 391: QuantTensor not valid.
# Input tensor: tensor([[3690.7102, 1429.3867]])
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: 0.00000002 %
# Narrowing search range to [0.20851272, 0.29630333]
#
# Iteration 7
#
# Running experiment with scale: 0.23777626
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: 0.00000001 %
#
# Running experiment with scale: 0.26703979
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: -0.00000002 %
# Narrowing search range to [0.20851272, 0.26703979]
#
# Iteration 8
#
# Running experiment with scale: 0.22802174
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: 0.00000008 %
#
# Running experiment with scale: 0.24753077
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: 0.00000000 %
# Narrowing search range to [0.22802174, 0.26703979]
#
# Iteration 9
#
# Running experiment with scale: 0.24102776
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: -0.00000011 %
#
# Running experiment with scale: 0.25403378
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: -0.00000004 %
# Narrowing search range to [0.24102776, 0.26703979]
#
# Iteration 10
#
# Running experiment with scale: 0.24969844
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: 0.00000001 %
#
# Running experiment with scale: 0.25836912
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: -0.00000004 %
# Narrowing search range to [0.24102776, 0.25836912]
#
# Iteration 11
#
# Running experiment with scale: 0.24680821
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: 0.00000000 %
#
# Running experiment with scale: 0.25258866
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: -0.00000002 %
# Narrowing search range to [0.24102776, 0.25258866]
#
# Iteration 12
#
# Running experiment with scale: 0.24488139
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: 0.00000007 %
#
# Running experiment with scale: 0.24873503
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: -0.00000003 %
# Narrowing search range to [0.24488139, 0.25258866]
#
# Iteration 13
#
# Running experiment with scale: 0.24745048
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: 0.00000017 %
#
# Running experiment with scale: 0.25001957
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: 0.00000006 %
# Narrowing search range to [0.24745048, 0.25258866]
#
# Iteration 14
#
# Running experiment with scale: 0.24916321
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: -0.00000004 %
#
# Running experiment with scale: 0.25087594
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Error occurred in run 438: QuantTensor not valid.
# Input tensor: tensor([[204.2130, 314.5984]])
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: 0.00000001 %
# Narrowing search range to [0.24916321, 0.25258866]
#
# Iteration 15
#
# Running experiment with scale: 0.25030503
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: -0.00000007 %
#
# Running experiment with scale: 0.25144685
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: 0.00000002 %
# Narrowing search range to [0.25030503, 0.25258866]
#
# Iteration 16
#
# Running experiment with scale: 0.25106624
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: -0.00000011 %
#
# Running experiment with scale: 0.25182745
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: -0.00000005 %
# Narrowing search range to [0.25106624, 0.25258866]
#
# Iteration 17
#
# Running experiment with scale: 0.25157371
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: 0.00000009 %
#
# Running experiment with scale: 0.25208119
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: 0.00000007 %
# Narrowing search range to [0.25157371, 0.25258866]
#
# Iteration 18
#
# Running experiment with scale: 0.25191203
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: -0.00000008 %
#
# Running experiment with scale: 0.25225035
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: -0.00000010 %
# Narrowing search range to [0.25157371, 0.25225035]
#
# Iteration 19
#
# Running experiment with scale: 0.25179926
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: 0.00000004 %
#
# Running experiment with scale: 0.25202480
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: -0.00000000 %
# Narrowing search range to [0.25179926, 0.25225035]
#
# Iteration 20
#
# Running experiment with scale: 0.25194962
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: -0.00000003 %
#
# Running experiment with scale: 0.25209998
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: -0.00000001 %
# Narrowing search range to [0.25194962, 0.25225035]
#
# Iteration 21
#
# Running experiment with scale: 0.25204986
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: -0.00000011 %
#
# Running experiment with scale: 0.25215011
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: -0.00000012 %
# Narrowing search range to [0.25194962, 0.25215011]
#
# Iteration 22
#
# Running experiment with scale: 0.25201645
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: -0.00000008 %
#
# Running experiment with scale: 0.25208328
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: 0.00000003 %
# Narrowing search range to [0.25201645, 0.25215011]
#
# Iteration 23
#
# Running experiment with scale: 0.25206100
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: -0.00000002 %
#
# Running experiment with scale: 0.25210555
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: 0.00000002 %
# Narrowing search range to [0.25206100, 0.25215011]
#
# Iteration 24
#
# Running experiment with scale: 0.25209070
# Error occurred in run 12: QuantTensor not valid.
# Input tensor: tensor([[1470.9492,  763.5827]])
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Error occurred in run 333: QuantTensor not valid.
# Input tensor: tensor([[3176.3428, 2339.9058]])
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: -0.00000007 %
#
# Running experiment with scale: 0.25212040
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: 0.00000011 %
# Narrowing search range to [0.25206100, 0.25212040]
#
# Iteration 25
#
# Running experiment with scale: 0.25208080
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: 0.00000001 %
#
# Running experiment with scale: 0.25210060
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: 0.00000014 %
# Narrowing search range to [0.25206100, 0.25210060]
#
# Iteration 26
#
# Running experiment with scale: 0.25207420
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: 0.00000002 %
#
# Running experiment with scale: 0.25208740
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: 0.00000011 %
# Narrowing search range to [0.25206100, 0.25208740]
#
# Iteration 27
#
# Running experiment with scale: 0.25206980
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: 0.00000007 %
#
# Running experiment with scale: 0.25207860
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: -0.00000010 %
# Narrowing search range to [0.25206100, 0.25207860]
#
# Iteration 28
#
# Running experiment with scale: 0.25206687
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: -0.00000006 %
#
# Running experiment with scale: 0.25207274
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: 0.00000013 %
# Narrowing search range to [0.25206100, 0.25207274]
#
# Iteration 29
#
# Running experiment with scale: 0.25206491
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: 0.00000001 %
#
# Running experiment with scale: 0.25206882
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: -0.00000012 %
# Narrowing search range to [0.25206100, 0.25206882]
#
# Iteration 30
#
# Running experiment with scale: 0.25206361
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: 0.00000006 %
#
# Running experiment with scale: 0.25206622
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: -0.00000006 %
# Narrowing search range to [0.25206100, 0.25206622]
#
# Iteration 31
#
# Running experiment with scale: 0.25206274
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Error occurred in run 709: QuantTensor not valid.
# Input tensor: tensor([[1976.4240,  484.9687]])
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: -0.00000005 %
#
# Running experiment with scale: 0.25206448
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: -0.00000004 %
# Narrowing search range to [0.25206274, 0.25206622]
#
# Iteration 32
#
# Running experiment with scale: 0.25206390
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: 0.00000005 %
#
# Running experiment with scale: 0.25206506
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: 0.00000007 %
# Narrowing search range to [0.25206274, 0.25206506]
#
# Iteration 33
#
# Running experiment with scale: 0.25206351
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: -0.00000004 %
#
# Running experiment with scale: 0.25206429
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: 0.00000006 %
# Narrowing search range to [0.25206274, 0.25206429]
#
# Iteration 34
#
# Running experiment with scale: 0.25206326
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: -0.00000004 %
#
# Running experiment with scale: 0.25206377
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: 0.00000002 %
# Narrowing search range to [0.25206326, 0.25206429]
#
# Iteration 35
#
# Running experiment with scale: 0.25206360
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: -0.00000008 %
#
# Running experiment with scale: 0.25206394
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: -0.00000002 %
# Narrowing search range to [0.25206360, 0.25206429]
#
# Optimization complete
# Optimal scale found: 0.25206394
#
# Running final experiment with optimal scale
#
# Running experiment with scale: 0.25206394
# Completed 100 runs
# Completed 200 runs
# Completed 300 runs
# Completed 400 runs
# Completed 500 runs
# Completed 600 runs
# Completed 700 runs
# Completed 800 runs
# Completed 900 runs
# Completed 1000 runs
# Experiment results - Median error: 0.00000006 %
#
# Final results:
# Optimal scale: 0.25206394
# Optimal median error: 0.00000006 %

# %%
# Plot error distribution for the optimal scale
scale = optimal_scale

# %%
# Initialize model and set device
hidden_sizes = [core.N_HIDDEN_1, core.N_HIDDEN_2]
device = torch.device('cpu')
model = core.Digital_twin(core.N_INPUT, 1, hidden_sizes, scale, device).to(device)

errors = []

# Run inference once to cache quantized weights and biases
in_float = create_input_tensor(core.N_INPUT, scale, device)
model.eval()
out_brevitas = model(in_float)

# Extract and convert weights and biases to numpy arrays
W1_sw = model.fc1.quant_weight().int().cpu().numpy().astype(np.int64)
b1_sw = model.fc1.quant_bias().int().cpu().numpy().astype(np.int64).reshape(-1, 1)
W2_sw = model.fc2.quant_weight().int().cpu().numpy().astype(np.int64)
b2_sw = model.fc2.quant_bias().int().cpu().numpy().astype(np.int64).reshape(-1, 1)
W3_sw = model.fc3.quant_weight().int().cpu().numpy().astype(np.int64)
b3_sw = model.fc3.quant_bias().int().cpu().numpy().astype(np.int64).reshape(-1, 1)

# Perform multiple runs to compare results
for _ in range(N_RUNS):
  in_float = create_input_tensor(core.N_INPUT, scale, device)
  try:
      out_brevitas = model(in_float)
      out_brevitas_int = out_brevitas.int().cpu().numpy().astype(np.int64)
  except Exception as e:
      print(f"Error occurred: {e}")
      print(f"Input tensor: {in_float}")
      continue

  X_sw = in_float.divide(scale).view(-1, 1).cpu().numpy().astype(np.int64)
  Y_pred_64 = forward_pass_sw(X_sw, W1_sw, b1_sw, W2_sw, b2_sw, W3_sw, b3_sw)

  # Calculate and append errors for both outputs
  for i in range(2):
      error = (out_brevitas_int[:, i] - Y_pred_64[i, 0]) / Y_pred_64[i, 0]
      errors.append(error[0])

# Calculate and print error statistics
stats = calculate_error_stats(errors)
print("Error Statistics:")
for stat_name, stat_value in stats.items():
  print(f"  {stat_name.capitalize()}: {stat_value} %")

# Plot error distribution
plt.figure(figsize=(10, 5))
plt.hist(errors, bins=50, edgecolor='black')
plt.title('Error Distribution')
plt.xlabel('Error (%)')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()
# Out:
# Error Statistics:
#   Max: 8.2600834358437e-05 %
#   Min: -1.4035131283419692e-06 %
#   Mean: 4.4403784789067655e-07 %
#   Median: 4.458280418922854e-08 %
#   Std: 5.8302058431252844e-06 %
#   25th_percentile: -3.4995955109457283e-08 %
#   75th_percentile: 1.2458905526277283e-07 %
